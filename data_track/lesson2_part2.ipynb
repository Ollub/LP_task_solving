# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5AB0-BEDC
#
#  Directory of C:\Users\o84083853\LearnPython\LP_task_solving\data_track
#
# 25.11.2018  11:56    <DIR>          .
# 25.11.2018  11:56    <DIR>          ..
# 25.11.2018  11:56    <DIR>          .ipynb_checkpoints
# 22.11.2018  15:14         3я492я172 bus_stops.csv
# 23.11.2018  18:15    <DIR>          env
# 23.11.2018  19:36           117я162 lesson1.ipynb
# 25.11.2018  11:44            22я531 lesson2.ipynb
# 25.11.2018  11:55                72 lesson2_part2.ipynb
#                4 File(s)      3я631я937 bytes
#                4 Dir(s)   8я085я676я032 bytes free

# %%
stations = pd.read_csv(open('bus_stops.csv', 'r', encoding='cp1251'), sep=';')

# %%
stations.head(10)
# Out:
#    ID                                               Name  Longitude_WGS84  \
# 0   7  «Дербеневская наб.», 3-й Дербеневский переулок...        37.655164
# 1  11  «Наб. Тараса Шевченко», набережная Тараса Шевч...        37.572409
# 2  12  «Наб. Тараса Шевченко», набережная Тараса Шевч...        37.572716
# 3  27                «ВКНЦ», 3-я Черепковская улица (27)        37.375509
# 4  33      «Новосущевская ул.», улица Сущёвский Вал (33)        37.603376
# 5  35          «Керамический пр.», Дубнинская улица (35)        37.557246
# 6  36                «Ин-т Стали», Дубнинская улица (36)        37.557291
# 7  37                «Мкр. Дубки», Дубнинская улица (37)        37.557307
# 8  38                «Д/к Юность», Дубнинская улица (38)        37.557364
# 9  39  «Баскетбольная школа», улица 800-летия Москвы ...        37.556361
#
#    Latitude_WGS84                      Street  \
# 0       55.725668   3-й Дербеневский переулок
# 1       55.749444  набережная Тараса Шевченко
# ...

# %% [markdown]
# ## How to research function
# 1. ? pd.read_csv
# 2. place the cursor on the function and press shift+tab or sh+t+t to show details

# %%
stations_count = stations.groupby(['Street']).size()

# %%
type(stations_count)
# Out:
# pandas.core.series.Series

# %%
stations_count.sort_values(ascending=False)
# Out:
# Street
# проезд без названия            469
# Варшавское шоссе               162
# Калужское шоссе                132
# шоссе Энтузиастов               85
# Дмитровское шоссе               76
# Боровское шоссе                 75
# проспект Мира                   72
# Ленинский проспект              68
# Чертановская улица              64
# проспект Вернадского            64
# Каширское шоссе                 60
# Ленинградское шоссе             56
# Профсоюзная улица               55
# Волгоградский проспект          50
# Волоколамское шоссе             46
# Люблинская улица                45
# Севастопольский проспект        45
# Центральная улица               43
# Алтуфьевское шоссе              43
# Зелёный проспект                42
# Рязанский проспект              42
# Мичуринский проспект            41
# Первомайская улица              40
# Рублёвское шоссе                40
# Ломоносовский проспект          38
# Шоссейная улица                 38
# ...

# %% [markdown]
# #### variable didn't change the value
# there are two ways to change it:
# 1. var = var......
# 2. use set argument inplace=True

# %%
stations_count.sort_values(ascending=False, inplace=True)

# %%
stations_count[1:10]
# Out:
# Street
# Варшавское шоссе        162
# Калужское шоссе         132
# шоссе Энтузиастов        85
# Дмитровское шоссе        76
# Боровское шоссе          75
# проспект Мира            72
# Ленинский проспект       68
# Чертановская улица       64
# проспект Вернадского     64
# dtype: int64

# %%
pavilion_count = stations.groupby(['Street', 'Pavilion']).size()
print(pavilion_count)
# Out:
# Street                         Pavilion
# 1-й Ботанический проезд        нет          1
# 1-й Боткинский проезд          да           2
# 1-й Варшавский проезд          да           2
# 1-й Вешняковский проезд        да           1
#                                нет          1
# 1-й Войковский проезд          да           1
#                                нет          1
# 1-й Волоколамский проезд       да           4
# 1-й Дачно-Мещерский проезд     нет          4
# 1-й Дербеневский переулок      да           1
#                                нет          2
# 1-й Западный проезд            да           2
# 1-й Капотнинский проезд        да          10
#                                нет          3
# 1-й Кожуховский проезд         да           1
# 1-й Котляковский переулок      нет          2
# 1-й Красногвардейский проезд   да           3
#                                нет          2
# 1-й Краснокурсантский проезд   нет          2
# ...
